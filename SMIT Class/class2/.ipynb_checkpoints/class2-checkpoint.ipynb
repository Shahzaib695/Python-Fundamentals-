# %%
print(type("hello"));
# Out:
# <class 'str'>

# %%
name = input("Enter Your Name");
print("My Name Is " + name);
# Out:
# Enter Your Name Shahzaib
# My Name Is Shahzaib

# %%
course = "Ai And Data Science";
print("The course is " , course);
print(course);
# Out:
# The course is  Ai And Data Science
# Ai And Data Science

# %%
marks = int(input("Enter Your Marks"));
print(marks);
print(f"Your score is {marks}");
# Out:
# Enter Your Marks 4.66
# 4.66
# Your score is 4.66

# %%
float_value = 3.4;
print(float_value);
print(type(float_value))
# Out:
# 3.4
# <class 'float'>

# %% [markdown]
# LEGAL AND ILLEGAL VARIABLE

# %%
# • A variable name can contain alphabets, digits, and underscores.
# • A variable name can only start with an alphabet and underscores.
# • A variable name can’t start with a digit.
# • No while space is allowed to be used inside a variable name.
# • No reserve word can be used as a variable name.

# %%
# floar division
# florr division

# %%
# Operators
# Assignment
# Comparision/Relational
# Logical
# Arthimetic

# %% [markdown]
# Operator Precedence \n
# Pemdas

# %%
100+300
# Out:
# 400

# %%
2*9
# Out:
# 18

# %%
10/2 #float division
# Out:
# 5.0

# %%
10//2 #florr division ideal for even
# Out:
# 5

# %%
2**3 #exponent power 2^3
# Out:
# 8

# %%
9**4
# Out:
# 6561

# %%
81%8
# Out:
# 1

# %%
# comparision operator ka output boolean me ata hai

# %%
100 > 200
# Out:
# False

# %%
200 > 123
# Out:
# True

# %%
20 >= 8
# Out:
# True

# %%
20<=98 #less than or equal too
# Out:
# True

# %%
200 < 150
# Out:
# False

# %%
900 == 700
# Out:
# False

# %% [markdown]
# LOGICAL OPERATOR
