# %%
print("Hello World")
# Out:
# Hello World

# %%
print(123456789)
# Out:
# 123456789

# %% [markdown]
# Data Types
# Integer
# String
# Float
# Boolean

# %% [markdown]
# String

# %%
print("Shahzaib")
# Out:
# Shahzaib

# %%
print("123456")
# Out:
# 123456

# %%
print(type("Hello"))
# Out:
# <class 'str'>

# %% [markdown]
# Integer

# %%
print(123)
# Out:
# 123

# %%
print(type(123))
# Out:
# <class 'int'>

# %% [markdown]
# Float

# %%
print(1.23)
# Out:
# 1.23

# %%
print(type(1.23))
# Out:
# <class 'float'>

# %%
print("Artificial Intelligence (AI)\n and Data Science are closely\n related, high-growth fields driving modern technology, with AI\n focusing on building intelligent systems that act \nautonomously, while Data Science extracts insights from\n data to guide decisions. AI creates systems (like chatbots) using\n machine learning, whereas data\n science analyzes past trends to predict future ones. ")
# Out:
# Artificial Intelligence (AI)
#  and Data Science are closely
#  related, high-growth fields driving modern technology, with AI
#  focusing on building intelligent systems that act
# autonomously, while Data Science extracts insights from
#  data to guide decisions. AI creates systems (like chatbots) using
#  machine learning, whereas data
#  science analyzes past trends to predict future ones.
