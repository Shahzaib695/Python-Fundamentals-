# %% [markdown]
# ###   ERROR HANDLING

# %% [markdown]
# ###### Error

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %%
print(hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(hello)
#
# NameError: name 'hello' is not defined

# %%
int("iu")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 int("iu")
#
# ValueError: invalid literal for int() with base 10: 'iu'

# %%
a = int(input("ENter a number"))
b = int(input("Enter a secound number"))
try:
    print(a/b)
    
except ZeroDivisionError:
    print("Conplex")
# Out:
# ENter a number90
# Enter a secound number0
# Conplex

# %%
try:
    
    a = int(input("ENter a number"))
    b = int(input("Enter a secound number"))
    print(a/b)
    print(divide)
except ZeroDivisionError:
    print("0 sai divie")
except NameError:
    print("AB ni aye ga")
# Out:
# ENter a numberi
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 try:
# ----> 3     a = int(input("ENter a number"))
#       4     b = int(input("Enter a secound number"))
#       5     print(a/b)
#
# ValueError: invalid literal for int() with base 10: 'i'

# %%
try:
    
    a = int(input("ENter a number"))
    b = int(input("Enter a secound number"))
    print(a/b)
    print(divide)
except ZeroDivisionError:
    print("0 sai divie")
except NameError:
    print("AB ni aye ga")
except ValueError:
    print("Ab ni aye ga value error")
# Out:
# ENter a number23
# Enter a secound number3
# 7.666666666666667
# AB ni aye ga

# %% [markdown]
# ###  Exception

# %%
try:
    
    a = int(input("ENter a number"))
    b = int(input("Enter a secound number"))
    print(a/b)
    print(divide)
except Exception  as e:
    print("Error resolved",e)
# Out:
# ENter a number8
# Enter a secound numberblw
# Error resolved invalid literal for int() with base 10: 'blw'

# %%
with open("file.txt","r") as f:
    f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 with open("file.txt","r") as f:
#       2     f.read()
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:286, in _modified_open(file, *args, **kwargs)
#     279 if file in {0, 1, 2}:
#     280     raise ValueError(
#     281         f"IPython won't let you open fd={file} by default "
#     282         "as it is likely to crash IPython. If you know what you are doing, "
#     283         "you can use builtins' open."
#     284     )
# --> 286 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'file.txt'

# %%
student  = ["hamza","imran khan","nawaz","Bilawal","zaka"]

# %%
student  = ["hamza","imran khan","nawaz","Bilawal","zaka"]
try:
    with open("student.txt","w+") as f:
            f.write(student.pop())
            f.seek(0)
            print(f.read())
except ValueError:
    print("Ab ni aye ga value error")
# Out:
# zaka

# %% [markdown]
# ### finally

# %%
try:
    a = int(input("ENter a number"))
    b = int(input("Enter a secound number"))
    print(a/b)
#     print(divide)
except Exception  as e:
    print("Error resolved",e)
finally:
    print("YEh to har waqt chale ga chaye error ho ya na hon")
# Out:
# ENter a number12
# Enter a secound number2
# 6.0
# YEh to har waqt chale ga chaye error ho ya na hon

# %% [markdown]
# ### Raise Exception

# %%
age = int(input("Enter your age"))
if age <10 or age >100:
    raise Exception("Age limit")
print(age)
# Out:
# Enter your age3
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[59], line 3
#       1 age = int(input("Enter your age"))
#       2 if age <10 or age >100:
# ----> 3     raise Exception("Age limit")
#       4 print(age)
#
# Exception: Age limit

# %%
names = ["furqan","jameel","man","khan"]

# %%
for name in names:
    if name =="jameel" or name == "khan":
        raise Exception(f"{name} yeh log kharab hai ")
print(name)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[65], line 3
#       1 for name in names:
#       2     if name =="jameel" or name == "khan":
# ----> 3         raise Exception(f"{name} yeh log kharab hai ")
#       4 print(name)
#
# Exception: jameel yeh log kharab hai
